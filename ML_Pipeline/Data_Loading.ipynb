# %%
# I will start loading both consolidates datasets

transactions = spark.table("fraud_unified.unified_fraud_transactions")
applications = spark.table("fraud_gold.account_application_fraud")

# %%
# Schema is checked to validate data cleaning

transactions.printSchema()
applications.printSchema()

transactions.groupBy("is_fraud").count().show()
applications.groupBy("is_fraud").count().show()
